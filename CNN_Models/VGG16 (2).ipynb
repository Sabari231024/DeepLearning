# %%
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
import torchvision.datasets as datasets

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Dataset preparation

# %%
train_data = datasets.imagenette(root="train",train=True,download=True)
test_data = datasets.imagenette(root="test",train=False,download=True)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to train/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:17<00:00, 9792700.01it/s]
# Extracting train/cifar-10-python.tar.gz to train
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to test/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:10<00:00, 15822700.73it/s]
# Extracting test/cifar-10-python.tar.gz to test
